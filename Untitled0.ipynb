# %% [markdown]
# <a href="https://colab.research.google.com/github/junhyeok-a/AIpythoon/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
pd.read_csv('Iris.csv')
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df = pd.read_csv("Iris.csv")
print(len(df))
# Out:
# 150

# %%
import pandas as pd

# Load the dataset
df = pd.read_csv("Iris.csv")

# 1. View total number of samples and columns
print("Total samples:", len(df))
print("Total columns:", len(df.columns))

# 2. Column names
print("Column names:", df.columns.tolist())

# 3. Check for null values and numeric columns
print("Null values per column:\n", df.isnull().sum())
print("Number of numeric columns:", df.select_dtypes(include='number').shape[1])

# 4. Basic statistics
print("Average Sepal Length:", df["SepalLengthCm"].mean())
print("Max Petal Width:", df["PetalWidthCm"].max())

# 5. Count per species
species_counts = df["Species"].value_counts()
print("Counts per species:\n", species_counts)
print("Are counts equal across species?", species_counts.nunique() == 1)

# 6. Filtering
petal_length_filter = df[df["PetalLengthCm"] > 2.0]
print("Rows with Petal Length > 2.0:", len(petal_length_filter))

sepal_width_filter = df[df["SepalWidthCm"] > 3.5]
print("Rows with Sepal Width > 3.5:", len(sepal_width_filter))
# Out:
# Total samples: 150
# Total columns: 6
# Column names: ['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm', 'Species']
# Null values per column:
#  Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64
# Number of numeric columns: 5
# Average Sepal Length: 5.843333333333334
# Max Petal Width: 2.5
# Counts per species:
#  Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64
# Are counts equal across species? True
# Rows with Petal Length > 2.0: 100
# Rows with Sepal Width > 3.5: 18

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("Iris.csv")

# Problem 8
versicolor_mean_petal_length = df[df["Species"] == "Iris-versicolor"]["PetalLengthCm"].mean()
print("Mean Petal Length (versicolor):", versicolor_mean_petal_length)

virginica_max_sepal_width = df[df["Species"] == "Iris-virginica"]["SepalWidthCm"].max()
print("Max Sepal Width (virginica):", virginica_max_sepal_width)

# Problem 9
plt.hist(df["PetalLengthCm"], bins=20, color="skyblue", edgecolor="black")
plt.title("Histogram of Petal Length")
plt.xlabel("Petal Length (cm)")
plt.ylabel("Frequency")
plt.show()

# Problem 10
plt.scatter(df["PetalLengthCm"], df["PetalWidthCm"], color="green", alpha=0.6)
plt.title("Petal Length vs Petal Width")
plt.xlabel("Petal Length (cm)")
plt.ylabel("Petal Width (cm)")
plt.show()

# Problem 11
sns.scatterplot(data=df, x="PetalLengthCm", y="PetalWidthCm", hue="Species")
plt.title("Scatterplot by Species")
plt.show()

# Problem 12
mean_values = df.groupby("Species")[["SepalLengthCm", "PetalWidthCm"]].mean()
print("Mean Sepal Length and Petal Width by Species:\n", mean_values)

# Problem 13
mean_petal_length = df.groupby("Species")["PetalLengthCm"].mean()
mean_petal_length.plot(kind="bar", color=["orange", "blue", "green"])
plt.title("Mean Petal Length by Species")
plt.ylabel("Petal Length (cm)")
plt.show()

# Problem 14
sns.boxplot(data=df, x="Species", y="PetalLengthCm")
plt.title("Boxplot of Petal Length by Species")
plt.show()
# Out:
# Mean Petal Length (versicolor): 4.26
# Max Sepal Width (virginica): 3.8
# Mean Sepal Length and Petal Width by Species:
#                   SepalLengthCm  PetalWidthCm
# Species
# Iris-setosa              5.006         0.244
# Iris-versicolor          5.936         1.326
# Iris-virginica           6.588         2.026
